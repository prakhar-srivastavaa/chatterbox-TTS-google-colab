# %%
# Clone the Chatterbox-TTS-Server repository
# !git clone https://github.com/devnen/Chatterbox-TTS-Server.git

# Navigate into the cloned directory
# %cd Chatterbox-TTS-Server

# Install core dependencies. The --index-url is for PyTorch with CUDA support.
# !pip install torch==2.5.1+cu121 torchaudio==2.5.1+cu121 torchvision==0.20.1+cu121 --index-url https://download.pytorch.org/whl/cu121 -q

# Install the Chatterbox library itself
# !pip install git+https://github.com/devnen/chatterbox.git -q

# Install other required packages for the server and audio processing
# !pip install fastapi uvicorn pyyaml soundfile librosa safetensors -q
# !pip install python-multipart requests jinja2 watchdog aiofiles unidecode inflect tqdm -q
# !pip install pydub audiotsm -q
# Out:
# Cloning into 'Chatterbox-TTS-Server'...
# remote: Enumerating objects: 302, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 302 (delta 135), reused 116 (delta 116), pack-reused 142 (from 1)
# Receiving objects: 100% (302/302), 18.94 MiB | 41.18 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# /content/Chatterbox-TTS-Server
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.4/780.4 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 97.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 118.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 112.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 18.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 73.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 22.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 114.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.2/225.2 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 79.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 26.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 121.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.4/226.4 kB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 109.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 37.5 MB/s eta 0:00:00
#   Building wheel for chatterbox-tts (pyproject.toml) ... done
#   Building wheel for s3tokenizer (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 7.7 MB/s eta 0:00:00

# %%
import threading
import time
import uvicorn
import gc
from google.colab.output import serve_kernel_port_as_window

# Clear existing servers and memory
# !fuser -k 8008/tcp 2>/dev/null || echo "Port clear"
# !pkill -f "uvicorn.*server" 2>/dev/null || echo "No running servers"
gc.collect()

# Define a function to run the server
def run_server():
    from server import app
    try:
        uvicorn.run(
            app,
            host="0.0.0.0",
            port=8008,
            log_level="warning",
            access_log=False
        )
    except Exception as e:
        print(f"❌ Server error: {e}")

# Start the server in a new thread
print("🚀 Starting TTS server...")
thread = threading.Thread(target=run_server, daemon=True)
thread.start()
time.sleep(25)  # Give the server time to start and load the model

print("🎉 Server ready! Click below:")
serve_kernel_port_as_window(8008)
